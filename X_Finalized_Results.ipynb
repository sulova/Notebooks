# %% [markdown]
# # Data Preparation

# %%
import geopandas as gpd
from osgeo import ogr

import gdal
import numpy as np
from pathlib import Path
import ogr
import pandas as pd
import rasterio
import gdal
from geopandas import GeoSeries, GeoDataFrame
from shapely.geometry.polygon import Polygon
from shapely.geometry.multipolygon import MultiPolygon

# %% [markdown]
# - A) Original Rio-Segura file (Check a structure of file)

# %%
cro_org = Path(f'../1_Documents/SR AH 2020-21 desagregado leñosos/Cultivos_regados_AH2021_v6.shp')
cro_org = gpd.read_file(cro_org)
cro_org = pd.DataFrame(cro_org)
cro_org.shape
# Out:
# (277695, 22)

# %%
cro_org.head(5)
cro_org.iloc[:,:18].head(5)
# Out:
#    Superficie C20_M10 C20_M11 C20_M12 C21_M01 C21_M02 C21_M03 C21_M04 C21_M05  \
# 0         462    None    None    None    None    None    None    None      H0
# 1         459    None    None    None    None    None    None    None      H0
# 2         298    None    None    None    None    None    None    None      H0
# 3         537    None    None    None    None    None    None    None      H0
# 4         151    None    None    None    None    None    None    None      H0
#
#   C21_M06 C21_M07 C21_M08 C21_M09 HI2021 HP2021 HV2021  HO20 C_AH2021
# 0       H       H    None    None   None   None   None  None       HU
# 1       H       H    None    None   None   None   None  None       HU
# 2       H       H    None    None   None   None   None  None       HU
# 3       H       H    None    None   None   None   None  None       HU
# 4       H       H    None    None   None   None   None  None       HU

# %%
cro_org.columns
# Out:
# Index(['Superficie', 'C20_M10', 'C20_M11', 'C20_M12', 'C21_M01', 'C21_M02',
#        'C21_M03', 'C21_M04', 'C21_M05', 'C21_M06', 'C21_M07', 'C21_M08',
#        'C21_M09', 'HI2021', 'HP2021', 'HV2021', 'HO20', 'C_AH2021',
#        'MESES_RIEG', 'COSECHAS', 'Cat_L_SP', 'geometry'],
#       dtype='object')

# %% [markdown]
# - B) Original Rio-Segura file Translated (Check a structure)

# %%
crop_2021 =  gpd.read_file('Final/crop_2021.shp')
crop_2021.shape
# Out:
# (277695, 25)

# %%
crop_2021.head(5)
# Out:
#    Superficie C20_M10 C20_M11 C20_M12 C21_M01 C21_M02 C21_M03 C21_M04 C21_M05  \
# 0         462    None    None    None    None    None    None    None      H0
# 1         459    None    None    None    None    None    None    None      H0
# 2         298    None    None    None    None    None    None    None      H0
# 3         537    None    None    None    None    None    None    None      H0
# 4         151    None    None    None    None    None    None    None      H0
#
#   C21_M06                        ...                         Herb_Summe  \
# 0       H                        ...                               None
# 1       H                        ...                               None
# 2       H                        ...                               None
# 3       H                        ...                               None
# 4       H                        ...                               None
#
#   Herb_Autum Seasons TotalCropM NumberHarv TreeType TreeType_T  \
# 0       None      HU          3          1     None       None
# 1       None      HU          3          1     None       None
# 2       None      HU          3          1     None       None
# 3       None      HU          3          1     None       None
# 4       None      HU          3          1     None       None
#
#         Seasons_T  Training                                           geometry
# 0  Family gardens         H  POLYGON ((537406.530500001 4216862.771999994, ...
# 1  Family gardens         H  POLYGON ((537406.530500001 4216862.771999994, ...
# 2  Family gardens         H  POLYGON ((537315.0019999996 4216616.410499991,...
# 3  Family gardens         H  POLYGON ((537317.1019999986 4216599.030499995,...
# 4  Family gardens         H  POLYGON ((537382.4605000004 4216870.851999988,...
#
# [5 rows x 25 columns]

# %%
crop_2021.columns
# Out:
# Index(['Superficie', 'C20_M10', 'C20_M11', 'C20_M12', 'C21_M01', 'C21_M02',
#        'C21_M03', 'C21_M04', 'C21_M05', 'C21_M06', 'C21_M07', 'C21_M08',
#        'C21_M09', 'Herb_Winte', 'Herb_Sprin', 'Herb_Summe', 'Herb_Autum',
#        'Seasons', 'TotalCropM', 'NumberHarv', 'TreeType', 'TreeType_T',
#        'Seasons_T', 'Training', 'geometry'],
#       dtype='object')

# %% [markdown]
# # Our Crop Classification Deliverables

# %%
perm =  gpd.read_file('crop-predictions.geojson')
herb =  gpd.read_file('herbaceous-probabilties.geojson')
print("Perm:", perm.shape, "Herb:",herb.shape)
# Out:
# Perm: (277199, 30) Herb: (277249, 33)

# %%
gdf = perm.merge(herb,on='xy',  how='left')
gdf = gdf.drop_duplicates(subset='xy',keep='first')
gdf.prediction.dropna()
gdf = merge_unique[['2101','2102','2103','2104','2105','2106','2107','2108','2109','2010','2011','2012','prediction', 'geometry_y','Superficie']]
print("GDF merged:", gdf.shape)

# Raname Columns and clsas values
gdf['Class'] = gdf['prediction'].replace({0:'Herbaceous',   1:'Low-density',
                                          2:'High-density', 3:'Vineyard',
                                          4:'Greenhouse',   5:'Family Gardens'})

gdf['Class_ES'] = gdf['Class'].replace({'Herbaceous':'H', 'Low-density':'LBC',
                                        'High-density': 'LAC',  'Vineyard':'VP',
                                        'Greenhouse':'INV',     'Family Gardens':'HU'})

gdf = gdf.rename(columns={'2101':'C21_M01','2102':'C21_M02','2103':'C21_M03','2104':'C21_M04',
                          '2105':'C21_M05','2106':'C21_M06','2107':'C21_M07','2108':'C21_M08',
                          '2109':'C21_M09','2010':'C20_M10','2011':'C20_M11','2012':'C20_M12'})
# Out:
# GDF merged: (277031, 15)
# /home/jovyan/.conda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/jovyan/.conda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for ind, column_name in enumerate(gdf.columns[:12]):
    gdf[column_name] = np.where((gdf.prediction == 0) & (gdf[column_name] >= 0.4), 1, gdf[column_name])
    gdf[column_name] = np.where((gdf.prediction == 5) & (gdf[column_name] >= 0.4), 1, gdf[column_name])
    gdf[column_name] = np.where((gdf.prediction == 0) & (gdf[column_name] <= 0.4), np.nan, gdf[column_name])
    gdf[column_name] = np.where((gdf.prediction == 5) & (gdf[column_name] <= 0.4), np.nan, gdf[column_name])
    gdf[column_name] = np.where((gdf.prediction != 0) & (gdf.Class_ES == 'LAC'), 'LAC', gdf[column_name])
    gdf[column_name] = np.where((gdf.prediction != 0) & (gdf.Class_ES == 'LBC'), 'LBC', gdf[column_name])
    gdf[column_name] = np.where((gdf.prediction == 4), np.nan, gdf[column_name])
    gdf[column_name] = np.where((gdf.prediction == 5) & (gdf[column_name]== '1.0'), "H", gdf[column_name])
    gdf[column_name] = np.where((gdf.prediction == 0) & (gdf[column_name] == '1.0'), 'H', gdf[column_name])

# %%
gdf = gdf.rename(columns={'geometry_y':'geometry'})
gdf = gdf.drop(columns=['prediction','Class'])
gdf = gpd.GeoDataFrame(gdf, crs="EPSG:4326", geometry='geometry')

# %%
gdf["geometry"] = [MultiPolygon([feature]) if isinstance(feature, Polygon) \
    else feature for feature in gdf["geometry"]]

# %%
gdf.shape
# Out:
# (277031, 15)

# %%
gdf
# Out:
#        C21_M01 C21_M02 C21_M03 C21_M04 C21_M05 C21_M06 C21_M07 C21_M08  \
# 0          LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 1          LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 2          LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 3          LBC     LBC     LBC     LBC     LBC     LBC     LBC     LBC
# 4          LBC     LBC     LBC     LBC     LBC     LBC     LBC     LBC
# 5          LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 6          LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 7          LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 8          LBC     LBC     LBC     LBC     LBC     LBC     LBC     LBC
# 9            H       H       H       H       H       H     nan     nan
# 10         LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 11         LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 12         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 13         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 14         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 15         LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 16         LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 17           H     nan     nan     nan     nan     nan     nan     nan
# 18         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 19         LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 20         LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 21         nan     nan     nan     nan     nan     nan     nan     nan
# 22           H     nan       H     nan     nan     nan     nan     nan
# 23           H       H       H       H       H     nan     nan     nan
# 24         nan     nan     nan       H       H       H     nan     nan
# 25         nan     nan     nan     nan       H       H       H     nan
# 26           H       H     nan     nan     nan       H       H     nan
# 27         LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# 28           H     nan     nan       H       H       H       H     nan
# 29         LAC     LAC     LAC     LAC     LAC     LAC     LAC     LAC
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 278577     nan       H       H       H       H       H       H       H
# 278578     nan       H       H       H       H       H       H       H
# 278579     nan       H       H       H       H       H       H       H
# 278580     nan       H       H     nan       H       H       H       H
# 278581     nan       H       H       H       H       H       H       H
# 278582     nan       H       H       H       H       H       H       H
# 278583     nan       H       H       H       H       H       H       H
# 278584     nan       H       H       H       H       H       H       H
# 278585     nan       H       H       H       H       H       H       H
# 278586     nan       H       H       H       H       H       H       H
# 278587     nan       H       H       H       H       H       H       H
# 278588     nan       H       H       H       H       H       H       H
# 278589     nan       H       H       H       H       H       H       H
# 278590     nan       H       H       H       H       H       H       H
# 278591     nan       H       H       H       H       H       H       H
# 278592     nan       H       H       H       H       H       H       H
# 278593     nan     nan     nan       H       H       H       H       H
# 278594     nan       H       H       H       H       H       H       H
# 278595     nan       H       H       H       H       H       H       H
# 278596     LBC     LBC     LBC     LBC     LBC     LBC     LBC     LBC
# 278597     nan       H       H       H       H       H       H       H
# 278598     nan       H       H       H       H       H       H       H
# 278599     nan     nan       H       H       H       H       H       H
# 278600     nan       H       H       H       H       H       H       H
# 278601     nan       H       H       H       H       H       H       H
# 278602     nan       H       H       H       H       H       H       H
# 278603     nan       H       H       H       H       H       H       H
# 278604     nan       H       H       H       H       H       H       H
# 278605     nan     nan       H       H       H       H       H       H
# 278606       H     nan     nan     nan       H       H     nan     nan
#
#        C21_M09 C20_M10 C20_M11 C20_M12  \
# 0          LAC     LAC     LAC     LAC
# 1          LAC     LAC     LAC     LAC
# 2          LAC     LAC     LAC     LAC
# 3          LBC     LBC     LBC     LBC
# 4          LBC     LBC     LBC     LBC
# 5          LAC     LAC     LAC     LAC
# 6          LAC     LAC     LAC     LAC
# 7          LAC     LAC     LAC     LAC
# 8          LBC     LBC     LBC     LBC
# 9          nan       H       H       H
# 10         LAC     LAC     LAC     LAC
# 11         LAC     LAC     LAC     LAC
# 12         NaN     NaN     NaN     NaN
# 13         NaN     NaN     NaN     NaN
# 14         NaN     NaN     NaN     NaN
# 15         LAC     LAC     LAC     LAC
# 16         LAC     LAC     LAC     LAC
# 17         nan     nan     nan       H
# 18         NaN     NaN     NaN     NaN
# 19         LAC     LAC     LAC     LAC
# 20         LAC     LAC     LAC     LAC
# 21         nan     nan     nan     nan
# 22         nan     nan     nan       H
# 23         nan       H       H       H
# 24         nan       H       H       H
# 25         nan       H       H       H
# 26         nan       H       H       H
# 27         LAC     LAC     LAC     LAC
# 28         nan     nan       H       H
# 29         LAC     LAC     LAC     LAC
# ...        ...     ...     ...     ...
# 278577       H       H       H       H
# 278578       H       H       H       H
# 278579       H       H       H       H
# 278580       H       H       H       H
# 278581       H       H       H       H
# 278582       H       H       H       H
# 278583       H       H       H       H
# 278584       H       H       H       H
# 278585       H       H       H       H
# 278586       H       H       H       H
# 278587       H       H       H       H
# 278588       H       H       H       H
# 278589       H       H       H       H
# 278590       H       H       H       H
# 278591       H       H       H       H
# 278592       H       H       H       H
# 278593       H       H       H       H
# 278594       H       H       H       H
# 278595       H       H       H       H
# 278596     LBC     LBC     LBC     LBC
# 278597       H       H       H       H
# 278598       H       H       H       H
# 278599       H       H       H       H
# 278600       H       H       H       H
# 278601       H       H       H       H
# 278602       H       H       H       H
# 278603       H       H       H       H
# 278604       H       H       H       H
# 278605       H       H       H       H
# 278606     nan     nan     nan       H
#
#                                                  geometry  Superficie Class_ES
# 0       (POLYGON ((-1.123112632649344 37.9534337461708...        3134      LAC
# 1       (POLYGON ((-0.8278106218991994 37.973399717851...       27430      LAC
# 2       (POLYGON ((-1.075998440878904 37.9576870404691...         586      LAC
# 3       (POLYGON ((-0.9260390227860397 37.886147792730...       18192      LBC
# 4       (POLYGON ((-0.8789629429613586 37.846351574096...         311      LBC
# 5       (POLYGON ((-1.03057539757508 37.66291525876795...        2283      LAC
# 6       (POLYGON ((-1.061221777404064 37.9616536969241...        3235      LAC
# 7       (POLYGON ((-1.050327748891738 37.9638220112831...         275      LAC
# 8       (POLYGON ((-1.115151996652562 38.0607409874936...       17485      LBC
# 9       (POLYGON ((-0.9850491729557022 37.789328581361...        6267        H
# 10      (POLYGON ((-0.9238345611536595 37.759090574311...        5737      LAC
# 11      (POLYGON ((-0.9633958917293652 37.805632633542...       47055      LAC
# 12      (POLYGON ((-1.190335209619997 37.5768404087097...       10142      INV
# 13      (POLYGON ((-0.8738315097334266 37.812495066331...        2756      INV
# 14      (POLYGON ((-1.124467180635443 37.7473263782308...        5609      INV
# 15      (POLYGON ((-0.8333315017196993 37.869125445646...        2159      LAC
# 16      (POLYGON ((-0.9656871945407961 37.783766425670...        6581      LAC
# 17      (POLYGON ((-0.8314328722067106 37.838994896256...         845        H
# 18      (POLYGON ((-1.025240335038906 37.7301912972545...        4214      INV
# 19      (POLYGON ((-1.0312030715483 37.72367046019421,...        5290      LAC
# 20      (POLYGON ((-0.8425248451546965 37.773232177805...       13306      LAC
# 21      (POLYGON ((-1.025567491084732 37.7153272131612...         751        H
# 22      (POLYGON ((-0.9006133556947714 37.710698256604...       63517        H
# 23      (POLYGON ((-0.9341777967127101 37.747400184870...         791        H
# 24      (POLYGON ((-0.9367950851269592 37.737542073915...        1126        H
# 25      (POLYGON ((-1.003082702879162 37.7834133151623...        6473        H
# 26      (POLYGON ((-0.7682284894273015 37.967283020267...       13949        H
# 27      (POLYGON ((-1.073846754903181 38.0034759337636...         230      LAC
# 28      (POLYGON ((-1.021901316001294 37.6577106125911...         545        H
# 29      (POLYGON ((-0.9836236945052325 37.746570343091...       18694      LAC
# ...                                                   ...         ...      ...
# 278577  (POLYGON ((-2.535909326882431 38.2268362869063...        1496       HU
# 278578  (POLYGON ((-2.691347400342401 38.1097561039315...         969       HU
# 278579  (POLYGON ((-2.69165982739984 38.1095242574811,...         539       HU
# 278580  (POLYGON ((-2.478618730782512 38.1632306887830...         629       HU
# 278581  (POLYGON ((-2.500484768039036 38.1864949179907...         280       HU
# 278582  (POLYGON ((-2.501113408019224 38.1857371144677...         287       HU
# 278583  (POLYGON ((-2.558066918404495 38.1038679628321...        6297       HU
# 278584  (POLYGON ((-2.60170295790053 38.09113951346974...         519       HU
# 278585  (POLYGON ((-2.601234388008734 38.0908963606515...         796       HU
# 278586  (POLYGON ((-2.533285532852306 38.2291924553051...        1115       HU
# 278587  (POLYGON ((-2.473861907511425 38.1888347226229...         405       HU
# 278588  (POLYGON ((-2.575966841367067 38.2275425309555...         429       HU
# 278589  (POLYGON ((-2.692606903611125 38.1024179504705...        1548       HU
# 278590  (POLYGON ((-2.692041036732153 38.1036825574476...         467       HU
# 278591  (POLYGON ((-2.691924785377545 38.1044114819813...         831       HU
# 278592  (POLYGON ((-2.500199149002907 38.1868157983419...         206       HU
# 278593  (POLYGON ((-2.502794404987889 38.1852565615137...         226       HU
# 278594  (POLYGON ((-2.551938732455483 38.0949643100246...        2705       HU
# 278595  (POLYGON ((-2.69358721477334 38.10763695947867...         643       HU
# 278596  (POLYGON ((-2.474625819315125 38.1890215799116...         635      LBC
# 278597  (POLYGON ((-2.579279945400474 38.2234163435225...         315       HU
# 278598  (POLYGON ((-2.494797113406706 38.1885061431586...         209       HU
# 278599  (POLYGON ((-2.494797113406706 38.1885061431586...         171       HU
# 278600  (POLYGON ((-2.534799239113737 38.2283931416905...         510       HU
# 278601  (POLYGON ((-2.692740219263629 38.1016666886010...         304       HU
# 278602  (POLYGON ((-2.693794624460387 38.1013518433573...         981       HU
# 278603  (POLYGON ((-2.694374314759876 38.1008164834683...         623       HU
# 278604  (POLYGON ((-2.693701346864083 38.1006402472694...         641       HU
# 278605  (POLYGON ((-2.502986464563055 38.1853557868248...         216       HU
# 278606  (POLYGON ((-1.821454609654102 37.2637900949603...       50673        H
#
# [277031 rows x 15 columns]

# %%
gdf.to_file('CropClassification2021__May2022.gpkg', driver='GPKG')
# Out:
# (277031, 16)
